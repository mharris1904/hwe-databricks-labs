-- %% [markdown]
-- # Week 3: Create Test Tables
--
-- This notebook creates simple test tables for the Week 3 lab.
-- These tables will be used to practice writing tests for SQL queries.
--
-- **Domain:** Employee/HR data (different from the bookstore domain in weeks 4-6)

-- %% [markdown]
-- ## Setup: Set Your Catalog
--
-- **IMPORTANT:** Before running any queries, set your assigned catalog name.

-- %%
-- TODO: Replace with your assigned catalog name
USE CATALOG redhatmatt;

-- %% [markdown]
-- ## Create Schema

-- %%
-- TODO: Create the week3_testing schema
create schema if not exists week3_testing_schema;
use schema week3_testing_schema;

-- %% [markdown]
-- ## Create Employees Table
--
-- Create a table to store employee information:
-- - employee_id (STRING)
-- - name (STRING)
-- - email (STRING)
-- - department (STRING)
-- - salary (DECIMAL(10,2))
-- - hire_date (DATE)

-- %%
-- TODO: Create the week3_testing.employees table
create table if not exists week3_testing_employees
(
  employee_id string
  , name string
  , email string
  , department string
  , salary decimal(10,2)
  , hire_date date
)

-- %% [markdown]
-- ## Create Departments Table
--
-- Create a table to store department information:
-- - dept_id (STRING)
-- - dept_name (STRING)
-- - manager_name (STRING)
-- - budget (DECIMAL(12,2))

-- %%
-- TODO: Create the week3_testing.departments table
create table if not exists week3_testing_departments
(
  dept_id string
  , dept_name string
  , manager_name string
  , budget decimal(12,2)
)
