-- %% [markdown]
-- # Drop Bronze Schema and Tables

-- %% [markdown]
-- ## Setup: Set Your Catalog
--
-- **IMPORTANT:** Before running any queries, set your assigned catalog name.

-- %%
-- TODO: Replace with your assigned catalog name
USE CATALOG redhatmatt;

-- %%
-- Drop the bronze.stores table
DROP TABLE IF EXISTS bronze.stores;

-- %%
-- Drop the bronze.books table
DROP TABLE IF EXISTS bronze.books;

-- %%
-- Drop the bronze.online_orders table
DROP TABLE IF EXISTS bronze.online_orders;

-- %%
-- Drop the bronze.instore_orders table
DROP TABLE IF EXISTS bronze.instore_orders;

-- %%
-- Drop the bronze.categories table
DROP TABLE IF EXISTS bronze.categories;

-- %%
-- Drop the bronze schema (use CASCADE to drop all tables)
DROP SCHEMA IF EXISTS bronze CASCADE;
